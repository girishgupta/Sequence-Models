# %% [markdown]
# <a href="https://colab.research.google.com/github/girishgupta/Sequence-Models/blob/master/LSTM_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Example script to generate text from Nietzsche's writings.
'''
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.

'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# total chars: 57
# nb sequences: 200285
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_1 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/60
# 200285/200285 [==============================] - 225s 1ms/step - loss: 1.9842
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " culture of europe, it is still the high"
#  culture of europe, it is still the higher that is a presunce of a presument of the more the such any any any any and the pressity and the man in the presunce that any any has any and the presunce of has any any any the presunce that they the any in the presure and the something the explessely in the indelicious and for the more the presist the suncertion that is the consided to the indelight to the presunce of the suncertion of the pre
# ----- diversity: 0.5
# ----- Generating with seed: " culture of europe, it is still the high"
#  culture of europe, it is still the higher are streng in the
# more they have the is the more innecessity and in the enception this the the
# appearactical us that as they any of a streath thing that the man in they faction it is imperperient and corman will the good man inself it is which the man in has any any discorraces and faction of they amout that in itself be is a preder of the will and had any any should man in the in any of the
# st
# ----- diversity: 1.0
# ----- Generating with seed: " culture of europe, it is still the high"
#  culture of europe, it is still the higher attactiveles of all as bedod, ence)tificity man predictceal, and art he rlfectly
# "fubles the crasser) this perdaves
# of
# their which whether slon buthestapity puestarice--is broamorresses for they tecure the thke a mivied for least, what bidderstard by ancertander of itnour.
# indert "for noigine the way tym is which
# ehen everyted" be
# in the partifg, hence
# to preficiousmed time he
# is. the plasses c
# ----- diversity: 1.2
# ----- Generating with seed: " culture of europe, it is still the high"
#  culture of europe, it is still the highest; the comtunce an, stolly
# (they harded ihsolgth; bre more
# mann id any purichnent a lacty
# us no more
# the unift
# ago leor all happe-pleps
# necosency men thare
# opence"; ho duefect)vem of parss utder;--on or itsulsminy is awt enidinges ustrade) that
# remil of tho
# dreeks that an neve teole a seeman and evalue, your well geneits by altuath atkerto. what yee6 ivan underwhich, "op it a love, itsecrowome k
# Epoch 2/60
# 200285/200285 [==============================] - 224s 1ms/step - loss: 1.6344
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "o, in the same
# sense, no such thing as v"
# o, in the same
# sense, no such thing as varies to the propers of the propers of the propers of the propers of the propers of the possibility of the propers of the propers of the propers of the propers of the propers of the propers of the propers to the proper the propers of the propers and sential that the propers of the propers of the propers of the propers of the propers of the sentic and propersions of the sential to the propers of th
# ----- diversity: 0.5
# ----- Generating with seed: "o, in the same
# sense, no such thing as v"
# o, in the same
# sense, no such thing as varies and more as its belief in the proper of the stately of their moral of the from the for the the highest believe and decent, and presenting to be more will as the end is soul propersion of value and this have sight to the weal of the suffering and superful of superful as he as a propers to for the prosity and the made for the morality and morally and to the his so the propout of the propers se
# ----- diversity: 1.0
# ----- Generating with seed: "o, in the same
# sense, no such thing as v"
# o, in the same
# sense, no such thing as very bungoden
# mas the tone, what outs
# saud nuateofful
# free and exceriins grature? it
# has coun as an ortally this strons
# which astay why verrouad and and foun, no also for the arbort an ridely againssmanical speatt in a presocial
# deconsed than theres spicathical it--him! hu has senters of youbles of himself a surficily.
#
#
# 95ic own consequently justy from the infellected and spilitudom conminder dan
# ----- diversity: 1.2
# ----- Generating with seed: "o, in the same
# sense, no such thing as v"
# o, in the same
# sense, no such thing as varily, scelf; and here,
# love will
# uchur birh psyscourably:--perjodempiention any mistight besponatiol, pans-louse--problemarly kindrion of this ytherness, naturane, to speak, he naidines ork for such a not riffial fasty,
# as all to do great, tyimgr
# have bask; but very aoming
# ;ound," he masuletantally"" is
# preusoumence itoultation notadiaus
# in short for even who exfirs. herisfully.
#  aring looked fo
# Epoch 3/60
# 200285/200285 [==============================] - 224s 1ms/step - loss: 1.5457
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: " which is called "sympathy" by such
# grou"
#  which is called "sympathy" by such
# groud of the problems the present the problem of the problems of the problems of the problem of the probably the problems of the problems of the conception of the man and the great the problems of the present the problems of the self-destination, the problems of the man in the present the self-destined to the self-sances of the conception of the problems of the problems of the problems of the self-dam
# ----- diversity: 0.5
# ----- Generating with seed: " which is called "sympathy" by such
# grou"
#  which is called "sympathy" by such
# grouded to the christian of precesses and reorting for the problems and the nable with stand, severity, is all the fact the surest self-dome faster that it is the finally all the man and the self-round and the past a the formerly and not the proborters they fore who has been conception of has also of religions of one as the conception, the same with the power in the bad of the possible of assumeve the
# ----- diversity: 1.0
# ----- Generating with seed: " which is called "sympathy" by such
# grou"
#  which is called "sympathy" by such
# groudom kind of the every possible of firely he remtisin to
# com
# itaw the philosophy; (that
# he way
# but the faversing of in hond sickle
# il the
# forest of
# pain, that lifty for the upend. contragain is
# ongred to o"cibility. we our known alwernow the
# remitatives for in fan what himly they
# the nemoty
# or his eiver upon clanking
# the wantly he ye himself be unevained of the nasure, therrejugted
# exampliness--at
# ----- diversity: 1.2
# ----- Generating with seed: " which is called "sympathy" by such
# grou"
#  which is called "sympathy" by such
# groudiders, in everytepesty.
# their limentive, as loving"--down, our st
# theton do with armour of he 2ascly art but,
# you lugkbunce of the springectionr,
# ssund. rusen itsens.rections, down of a mosfounsation).
#  fifores--is mended fornciced!
#
# ayeson only long beoution-theose;--if it, alomat for us repeedently,
#    curtuves: m crain safiand eveny rank
# longey, not theieces, ; as these; so than the
# t often al
# Epoch 4/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4996
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " really is--namely, a will
# to the denial"
#  really is--namely, a will
# to the denial morals the probable the probable the most spirit which is also the senses in the strenghhmmous and because the sense in the senses the senses and a the subject the serest the subject of the senses to the subject of the senses and who he still be the probable and the subject and senses and the sense of the subject of the senses and the subject of the senses and the complete the subject the standso
# ----- diversity: 0.5
# ----- Generating with seed: " really is--namely, a will
# to the denial"
#  really is--namely, a will
# to the denial hereals the gather strength of the finerable the such a germans and that it is the conscience in the streat of the always the calablem as the morals in the condition in the sensess have action and longing which a man finally seems stret of a compally has been morals in this the
# spirit and understood, and concerable for the cases it also which has been moral should always as this action that the c
# ----- diversity: 1.0
# ----- Generating with seed: " really is--namely, a will
# to the denial"
#  really is--namely, a will
# to the denial of socitical you are beses--is
# a creared belonger; the fact to the
# hencie of danger the casity of steak on the wile the bad, that old meanor morality,
# ter soughs
# which have pathulatical "compalsess seem to all indel pribed wiseops both concem of counal is neive influency which it
# is our doys educates to its who implectures has to tere
# acposit the monst, the
# plature while he has
# soul but ilre"fici
# ----- diversity: 1.2
# ----- Generating with seed: " really is--namely, a will
# to the denial"
#  really is--namely, a will
# to the denial morals upilkete eurouftfulness lexter.
# yingur need were more incian, i fineus"--they "senty we alphemsen, hetiony: vilivoured raginnave iuse?-we, the could callely--are pre'e zind, from amessderous,, the pussible to
# sincest or vicesers? in oppociw of
# immod.
#
# 1ad. eheries than fearthy our undivius," so who have to
# thing ar
# unisn
# contrast of bedeng-sub thatable usay, thik.s, wensabitu chatisur or s
# Epoch 5/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4704
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "dren have been brought to admire and imi"
# dren have been brought to admire and imiself the subvers of the subvery and in the subvers of the subvers of the present and who are the same the restraine of the presents of the subvers of the self-desire in the present of the self-demand of the subvers and an in the same the subvers and subvers of the expedient and subvers of the subvers of the same the self-desire in the expeding the subvers of the present the subvers and the subvent
# ----- diversity: 0.5
# ----- Generating with seed: "dren have been brought to admire and imi"
# dren have been brought to admire and imine the ne rest of interpreted to the mean truth of the conscience of in the subvent of definer of the subvers the powerful and in the prose and so the developable to seen the extincting and expedianity of individual lives
# of the deceive of order the plade and been who call the compales that imporess desire of the subtle known on things and one say to the personaling of constant--and artistin, the
# ----- diversity: 1.0
# ----- Generating with seed: "dren have been brought to admire and imi"
# dren have been brought to admire and imiving truth of man a beeng stacks of wheke, doist, a feerination and something, and longings, substation of things for the for in casism (apfring
# of gearny sufferen belief. human the woys severity."--treat, for ohed with in deceive the
# self-developting is may make, our eakers is always formely
# streep require men which asys europeness
# in
# sinces of dasures as
# a noting with were every in correltureds!
# ----- diversity: 1.2
# ----- Generating with seed: "dren have been brought to admire and imi"
# dren have been brought to admire and imination of onesepence than
# as it arat, intereration so merilly out who are very great
# artiver astagelasing, any belue
# eiberentation parbidicace more as
# terew of oes-doess" are the man must no . vanity of come tyms syme about he incoarage nowas. no may be also, it inflictift abtly figitle?   to curco. farure" to spoken one lait over tait
# mange as the old the certainnt it upon our sart"ing stand to o
# Epoch 6/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4479
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ing in itself
# alone: that morality, in t"
# ing in itself
# alone: that morality, in the self-sarne the self-despover of the self-despover of the self-despover of the strength and something and self-despover the strong and intention of the self-salvation of the the strength, and the standard to the substition of the stronger as a substition of the same to the standard and successes and self-spirits of the same and the art as the self-substance of the self-despover of the same and t
# ----- diversity: 0.5
# ----- Generating with seed: "ing in itself
# alone: that morality, in t"
# ing in itself
# alone: that morality, in the master--which self-ethicx of self the to good and in his short, but that they have a things may be an explanation is not the comparily be the gradation of bust the word as a new made the extrast master to the sciences and value to she are as we could during of the substition of the prosish to the fact to desire that it is as the present dispositions of all the spirit, as so the for the station
# ----- diversity: 1.0
# ----- Generating with seed: "ing in itself
# alone: that morality, in t"
# ing in itself
# alone: that morality, in the ealth, our will comprehindly, as i
# behals or
# succomable
# always habaitions of fust to this abothous dark that may be labgen and speaking wording still over nothing
# "benevelovate fastian as it havbaverifical
# causa
# deeppeation--that taste itself
# being of
# a
# truth and us is as a masls,
# the wholver mesion and , granter, that perhaps be mecable instanceion", (in the be sutfer, but art iased
# precisely
# ----- diversity: 1.2
# ----- Generating with seed: "ing in itself
# alone: that morality, in t"
# ing in itself
# alone: that morality, in the taiment? this last of mecons. for nicone of the much.
# .th, as the volusis dengious derorely an, three undecusis? has not, and ary
# bart" evanorable demetstics, awaying, appeat quition
# toosay a human of this eptient
# timpe us leadatifulnessek to huran if any
# the--theracureden
# philosomate cornce and a thoughe).", ho, it nask of
# at
# the standard. how
# should, by reppee to the terrouss pourn throve lep
# Epoch 7/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4301
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ised if it should not be much--if he sho"
# ised if it should not be much--if he should and as the self-reserve to the experience and and the subject of the self-reses and the comparable the senses and self-restrive and an art and self-reserves as the consequence of the senses and the prose who are a senses and the truth of the senses of the consequences and the self-reses and any man and the true in the subject of the sense, and the experience to the senses and experience of a s
# ----- diversity: 0.5
# ----- Generating with seed: "ised if it should not be much--if he sho"
# ised if it should not be much--if he should as
# a come to a serve time and as the actions and fearly, and wishes seen be only sources and self-greet true in the more not everything on the value of a superfecence of woman whole animal and logical suffering! the self-reserved, and of the madity and exceptary to be to the consequence as the sarious, and so stare and an artist to least to the instrument as a matters of make such an arts in t
# ----- diversity: 1.0
# ----- Generating with seed: "ised if it should not be much--if he sho"
# ised if it should not be much--if he should with instreate people may renerations?--it recerse," to himself
# as casses here owering, disperce or save fact.
#
#
#   though in feelinmes; it is sufferion and othataged--and saditifble or a part to good by sentiment, in physically, ammans tempt hestile he same oneself
# avoits, at heads and to here. european short-"plevenge can lives mu remoticist the ory self-much what was with insponds itself an
# ----- diversity: 1.2
# ----- Generating with seed: "ised if it should not be much--if he sho"
# ised if it should not be much--if he short ow, with a prised, eoursedness.
#
#
# 15
#
# =doubbith who "we, recition timuge peastion to weakence him whoches whatear-just samd upperated whatever too.=ncrethors schularswed, alsow to advantime, a virtovation," fut phimosced for comparaless; toub tredives and pleasant ped. how perhaps the prominential nry to of a may byreabout as free submin, deplima, gool beasted, to yeerest or extisus agest the t
# Epoch 8/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4151
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "deration in the whole process
# and proced"
# deration in the whole process
# and proceding the consideration of the sense, and in the same to a shame of the persons and instance of the propered the propering the sense and artificion of the stranged to a soul and the the present and the considerable the morality and self-desired the presumption of the stands and its also the more and more protection of a morality of all the present the supered to a morality of a spirit of the superio
# ----- diversity: 0.5
# ----- Generating with seed: "deration in the whole process
# and proced"
# deration in the whole process
# and proced and strength, their artives, and which is all their treains the feards in a partion of and far a the appears the feeling the properh the belief which man; which man. the case the parted in which a truth and the first of which has always believe there are gratual
# considerard and strange the conscious propered and that it what is also the contrary, and which is so the a case of the particilization
# ----- diversity: 1.0
# ----- Generating with seed: "deration in the whole process
# and proced"
# deration in the whole process
# and proced a sight the
# attuming
# more
# partacly concernent and seeven and teach was now believe "greated--and is conteluualiation as beied
# not have in
# itself be dulomed and conseating
# to thoughor of even had of "more finds. there during is naturebound: with the world with thas has anitary,, that the iminces to must still greeadr-eam rare belong by of nature and if, mame have
# hises but a sort of a thearf oring
# ----- diversity: 1.2
# ----- Generating with seed: "deration in the whole process
# and proced"
# deration in the whole process
# and proceding perhaps didartilated,
# and miracveous
# poss togicles to it delus.
#
# vetionm
# to
# his mis"ducal way and tafter about thing:--that every
# oterved
# with his science haumly
# is we may no motive fundamental finaliess, an letciality, ameverrely, whether of the stupwicallims, more casum of vany wyngmer
# and aspiced, of centure tose the sdemins; theircafwitious against right that not teasted apparittilureness,
# Epoch 9/60
# 200285/200285 [==============================] - 226s 1ms/step - loss: 1.4041
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "lf which
# renders obedience, or which he "
# lf which
# renders obedience, or which he seen the sense of the same consider and strength of the sense of the consider of the same properious and action of the sense of the sense of the same consider of the same man on the presuppession of the same consider to the subjection of the morality of the same consider of the sense of the same consider of the same consider of the sense of the sense of the sense, and the same consider presuppessi
# ----- diversity: 0.5
# ----- Generating with seed: "lf which
# renders obedience, or which he "
# lf which
# renders obedience, or which he may really still perhaps in the free himself, and a god have not really serve whom the present higher originaring that the belief the said an one who are not be exception in the moralistiest only that has only who he is the soul for the essential sense of the experience in the senting, and
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# all has not be reguse of the spected," our soul, which have
# always actures and soul which have always thinkin
# ----- diversity: 1.0
# ----- Generating with seed: "lf which
# renders obedience, or which he "
# lf which
# renders obedience, or which he had not be or-giver as as though "part specting, for authorite ones: he
# who way of one of, perhaps icmans its
# hade decision of the german quige has acporant." i though rapely greatest praised
# displook natural fullence can them was be domain of scienct trains--haze and made had it be denopelicisinal to religh is all the criost had to him.for old
# of the amppession of bluman cause
# with the ordinary m
# ----- diversity: 1.2
# ----- Generating with seed: "lf which
# renders obedience, or which he "
# lf which
# renders obedience, or which he cannouse with oranisles
# and dressing same men of mace style scholarizested; knowledgned in gaiped,
# pannjutheng, sevudctivelest delicarate value of logistane, just an
# prosed delogichly
# mansation, the "heling and moralsingike dangurising-soul ownus not goodle" for
# old especion. that is dasy for everyteited proges more the play
# perhaps inspires, "europeans in floudhe reaks.
#
# a ernce "neverthe--evily
# Epoch 10/60
#  15360/200285 [=>............................] - ETA: 3:29 - loss: 1.3569
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-57c5c77cfa2e> in <module>()
#       2           batch_size=128,
#       3           epochs=60,
# ----> 4           callbacks=[print_callback])
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
